# %% [markdown]
# ##USO DE LA TABLA DIMCATEGORIA

# %%
import pandas as pd

# %%
df = pd.read_csv('DimCategoria.csv', sep=';')

# %%
df.head(5)
# Out:
#   id_cat,nom_cat
# 0    1,Abarrotes
# 1      2,Lácteos
# 2     3,Gaseosas
# 3      4,Licores

# %%
dfCliente = pd.read_csv('DimCliente.csv', sep=';')
dfCliente.head(6)
# Out:
#     id_cli,tip_cli,nom_cli
# 0  1,1,RHSOFT - Tecnología
# 1            2,2,Juan Baca
# 2             3,2,Karla Li
# 3           4,2,José Chang
# 4             5,2,Ana Arce

# %%
dfEmpleado = pd.read_csv('DimEmpleado.csv', sep=';')
dfEmpleado.head(6)
# Out:
#   id_emp,nom_emp,ape_emp
# 0         1,Juan,Guillen
# 1       2,Luis,Galarreta
# 2               3,Ana,Li
# 3        4,Luisa,Almeyda
# 4    1002,Soledad,Corona
# 5        1003,asd,asdasd

# %%
dfFP = pd.read_csv('DimFP.csv', sep=';')
dfFP.head(6)
# Out:
#   id_fp,nom_fp
# 0    1,Contado
# 1    2,Crédito
# 2   3,Efectivo

# %%
dfMarca = pd.read_csv('DimMarca.csv', sep=';')
dfMarca.head(6)
# Out:
#   id_marca,nom_marca
# 0           1,Gloria
# 1            2,Laive
# 2         3,Donofrio
# 3              4,Ace
# 4          5,Costeño

# %%
dfMes = pd.read_csv('DimMes.csv', sep=';')
dfMes.head(6)
# Out:
#   id_mes,nom_mes
# 0        1,Enero
# 1      2,Febrero
# 2        3,Marzo
# 3        4,Abril
# 4         5,Mayo
# 5        6,Junio

# %%
dfProducto = pd.read_csv('DimProducto.csv', sep=';')
dfProducto.head(6)
# Out:
#   id_pro,nom_pro,pre_pro,id_sub,id_marca
# 0               1,Arroz costeño,8.50,1,1
# 1                2,Queso Laive,20.00,2,2
# 2               3,Queso Gloria,12.50,2,3
# 3            1002,Leche Gloria,14.80,3,4
# 4        1003,Azucar del norte,68.00,4,5
# 5         1004,Café Juan Vadez,38.00,5,6

# %%
dfSubCategoria = pd.read_csv('DimSubCategoria.csv', sep=';')
dfSubCategoria.head(6)
# Out:
#   id_sub,nom_sub,id_cat
# 0             1,Arroz,1
# 1            2,Azucar,1
# 2             3,Leche,2
# 3             4,Queso,2
# 4         5,Coca Cola,3
# 5             6,Fanta,3

# %%
dfTiempo = pd.read_csv('DimTiempo.csv', sep=';')
dfTiempo.head(6)
# Out:
#   id_tiempo,fecha,dia,id_mes,año,trimestre
# 0                 1,2024-01-15,15,1,2024,1
# 1                 2,2024-02-20,20,2,2024,1
# 2                 3,2024-03-10,10,3,2024,1
# 3                  4,2024-04-05,5,4,2024,2
# 4                 5,2024-05-12,12,5,2024,2
# 5                 6,2024-06-18,18,6,2024,2

# %%
dfVentas = pd.read_csv('facventas.csv', sep=';')
dfVentas.head(6)
# Out:
#   id_tiempo,id_cli,id_emp,id_pro,id_fp,can_pro,pre_pro,imp_pro
# 0                            1,1,1,1,1,5,12.50,62.50
# 1                             2,2,1,2,2,3,8.75,26.25
# 2                            3,1,2,1,1,2,12.50,25.00
# 3                            4,3,1,3,3,1,15.00,15.00
# 4                             5,2,2,2,2,4,8.75,35.00

# %% [markdown]
# ##INGRESO DE NUEVOS DATOS

# %%
new_data = {
    'id_cat,nom_cat': [
        '5,Panadería', '6,Frutas', '7,Verduras', '8,Carnes', '9,Pescados',
        '10,Congelados', '11,Dulces', '12,Snacks', '13,Limpieza', '14,Higiene Personal',
        '15,Farmacia', '16,Mascotas', '17,Juguetes', '18,Electrónica', '19,Ropa',
        '20,Calzado', '21,Muebles', '22,Jardinería', '23,Deportes', '24,Automotriz'
    ]
}
new_df = pd.DataFrame(new_data)
df = pd.concat([df, new_df], ignore_index=True)
display(df.tail(20))


##-------------------------------------------------------------------------------------------------------------------------------------------------------------
new_cliente_data = {
    'id_cli,tip_cli,nom_cli': [
        '6,2,Pedro Páramo', '7,2,Laura Esquivel', '8,1,Octavio Paz', '9,2,Elena Poniatowska', '10,2,Gabriel García Márquez',
        '11,1,Jorge Luis Borges', '12,2,Isabel Allende', '13,2,Mario Vargas Llosa', '14,1,Julio Cortázar', '15,2,Clarice Lispector',
        '16,2,Pablo Neruda', '17,1,Federico García Lorca', '18,2,Miguel de Cervantes', '19,2,William Shakespeare', '20,1,Jane Austen',
        '21,2,Leo Tolstoy', '22,2,Fyodor Dostoevsky', '23,1,Virginia Woolf', '24,2,George Orwell', '25,2,Aldous Huxley'
    ]
}
new_cliente_df = pd.DataFrame(new_cliente_data)
dfCliente = pd.concat([dfCliente, new_cliente_df], ignore_index=True)
display(dfCliente.tail(20))


##--------------------------------------------------------------------------------------------------------------------------------------------------------------------

new_empleado_data = {
    'id_emp,nom_emp,ape_emp': [
        '1004,Remigio,Huarcaya Almeyda', '1005,José,Murga', '1006,María,Pérez', '1007,Luis,González', '1008,Ana,Rodríguez',
        '1009,Carlos,Fernández', '1010,Sofía,Gómez', '1011,Diego,López', '1012,Valeria,Martínez', '1013,Andrés,Sánchez',
        '1014,Isabella,Pérez', '1015,Mateo,González', '1016,Lucía,Rodríguez', '1017,Gabriel,Fernández', '1018,Camila,Gómez',
        '1019,Sebastián,López', '1020,Daniela,Martínez', '1021,Javier,Sánchez', '1022,Valentina,Pérez', '1023,Alejandro,González'
    ]
}
new_empleado_df = pd.DataFrame(new_empleado_data)
dfEmpleado = pd.concat([dfEmpleado, new_empleado_df], ignore_index=True)
display(dfEmpleado.tail(20))

##--------------------------------------------------------------------------------------------------------------------------------------------------------------------

new_fp_data_10 = {
    'id_fp,nom_fp': [
        '24,Transferencia Bancaria', '25,Pago con QR', '26,Bono', '27,Cupón', '28,Tarjeta Regalo',
        '29,Crédito en Tienda', '30,Monedero Electrónico', '31,Pago a Plazos', '32,Factoring', '33,Confirming'
    ]
}
new_fp_df_10 = pd.DataFrame(new_fp_data_10)
dfFP = pd.concat([dfFP, new_fp_df_10], ignore_index=True)
display(dfFP.tail(10))

##--------------------------------------------------------------------------------------------------------------------------------------------------------------------

new_marca_data = {
    'id_marca,nom_marca': [
        '6,Coca-Cola', '7,Pepsi', '8,Fanta', '9,Sprite', '10,Nescafe',
        '11,Starbucks', '12,Lipton', '13,Arizona', '14,Bimbo', '15,Gamesa',
        '16,Marinela', '17,Sabritas', '18,Ruffles', '19,Doritos', '20,Cheetos',
        '21,Pringles', '22,Lay\'s', '23,Tostitos', '24,Kellogg\'s', '25,General Mills'
    ]
}
new_marca_df = pd.DataFrame(new_marca_data)
dfMarca = pd.concat([dfMarca, new_marca_df], ignore_index=True)
display(dfMarca.tail(20))

##--------------------------------------------------------------------------------------------------------------------------------------------------------------------

new_producto_data = {
    'id_pro,nom_pro,pre_pro,id_sub,id_marca': [
        '1007,Galletas Oreo,2.50,12,14', '1008,Papitas Lays,3.00,12,22', '1009,Chocolate Hershey\'s,5.00,11,10',
        '1010,Caramelos M&M\'s,4.00,11,10', '1011,Detergente Ace,15.00,13,4', '1012,Jabon Dove,8.00,14,1',
        '1013,Champú Head & Shoulders,10.00,14,7', '1014,Aspirinas Bayer,6.00,15,1', '1015,Curitas Band-Aid,3.50,15,1',
        '1016,Comida para perro Pedigree,20.00,16,1', '1017,Juguete para gato Whiskas,12.00,16,1', '1018,Peluche Oso,25.00,17,1',
        '1019,Carro a control remoto,50.00,17,1', '1020,Televisor Samsung,500.00,18,1', '1021,Laptop HP,800.00,18,1',
        '1022,Camiseta Nike,30.00,19,1', '1023,Pantalón Adidas,40.00,19,1', '1024,Zapatillas Puma,60.00,20,1',
        '1025,Sandalias Crocs,20.00,20,1', '1026,Silla de oficina,100.00,21,1'
    ]
}
new_producto_df = pd.DataFrame(new_producto_data)
dfProducto = pd.concat([dfProducto, new_producto_df], ignore_index=True)
display(dfProducto.tail(20))

##--------------------------------------------------------------------------------------------------------------------------------------------------------------------

new_subcategoria_data = {
    'id_sub,nom_sub,id_cat': [
        '9,Cereales,1', '10,Pastas,1', '11,Aceites,1', '12,Galletas,1', '13,Snacks,1',
        '14,Pan,5', '15,Pasteles,5', '16,Frutas Frescas,6', '17,Verduras Frescas,7', '18,Carnes Rojas,8',
        '19,Aves,8', '20,Pescados Frescos,9', '21,Mariscos,9', '22,Helados,10', '23,Verduras Congeladas,10',
        '24,Dulces,11', '25,Chocolates,11', '26,Papas Fritas,12', '27,Artículos de Limpieza,13', '28,Jabones,14'
    ]
}
new_subcategoria_df = pd.DataFrame(new_subcategoria_data)
dfSubCategoria = pd.concat([dfSubCategoria, new_subcategoria_df], ignore_index=True)
display(dfSubCategoria.tail(20))

##--------------------------------------------------------------------------------------------------------------------------------------------------------------------


new_tiempo_data = {
    'id_tiempo,fecha,dia,id_mes,año,trimestre': [
        '11,2024-11-01,1,11,2024,4', '12,2024-12-05,5,12,2024,4', '13,2025-01-10,10,1,2025,1',
        '14,2025-02-15,15,2,2025,1', '15,2025-03-20,20,3,2025,1', '16,2025-04-25,25,4,2025,2',
        '17,2025-05-30,30,5,2025,2', '18,2025-06-05,5,6,2025,2', '19,2025-07-10,10,7,2025,3',
        '20,2025-08-15,15,8,2025,3', '21,2025-09-20,20,9,2025,3', '22,2025-10-25,25,10,2025,4',
        '23,2025-11-30,30,11,2025,4', '24,2025-12-05,5,12,2025,4', '25,2026-01-10,10,1,2026,1',
        '26,2026-02-15,15,2,2026,1', '27,2026-03-20,20,3,2026,1', '28,2026-04-25,25,4,2026,2',
        '29,2026-05-30,30,5,2026,2', '30,2026-06-05,5,6,2026,2'
    ]
}
new_tiempo_df = pd.DataFrame(new_tiempo_data)
dfTiempo = pd.concat([dfTiempo, new_tiempo_df], ignore_index=True)
display(dfTiempo.tail(20))

##--------------------------------------------------------------------------------------------------------------------------------------------------------------------

new_ventas_data = {
    'id_tiempo,id_cli,id_emp,id_pro,id_fp,can_pro,pre_pro,imp_pro': [
        '7,6,1004,1007,4,10,2.50,25.00', '8,7,1005,1008,5,15,3.00,45.00', '9,8,1006,1009,6,5,5.00,25.00',
        '10,9,1007,1010,7,8,4.00,32.00', '11,10,1008,1011,8,2,15.00,30.00', '12,11,1009,1012,9,12,8.00,96.00',
        '13,12,1010,1013,10,6,10.00,60.00', '14,13,1011,1014,11,20,6.00,120.00', '15,14,1012,1015,12,25,3.50,87.50',
        '16,15,1013,1016,13,3,20.00,60.00', '17,16,1014,1017,14,7,12.00,84.00', '18,17,1015,1018,15,4,25.00,100.00',
        '19,18,1016,1019,16,1,50.00,50.00', '20,19,1017,1020,17,1,500.00,500.00', '21,20,1018,1021,18,1,800.00,800.00',
        '22,21,1019,1022,19,10,30.00,300.00', '23,22,1020,1023,20,15,40.00,600.00', '24,23,1021,1024,21,8,60.00,480.00',
        '25,24,1022,1025,22,12,20.00,240.00', '26,25,1023,1026,23,5,100.00,500.00'
    ]
}
new_ventas_df = pd.DataFrame(new_ventas_data)
dfVentas = pd.concat([dfVentas, new_ventas_df], ignore_index=True)
display(dfVentas.tail(20))
# Out:
#          id_cat,nom_cat
# 4           5,Panadería
# 5              6,Frutas
# 6            7,Verduras
# 7              8,Carnes
# 8            9,Pescados
# 9         10,Congelados
# 10            11,Dulces
# 11            12,Snacks
# 12          13,Limpieza
# 13  14,Higiene Personal
# 14          15,Farmacia
# 15          16,Mascotas
# 16          17,Juguetes
# 17       18,Electrónica
# 18              19,Ropa
# 19           20,Calzado
# 20           21,Muebles
# 21        22,Jardinería
# 22          23,Deportes
# 23        24,Automotriz

# %% [markdown]
# ##CREACION DEL NUEVO CSV

# %%
df.to_csv('DimCategoria_Actualizado.csv', index=False, sep=';')
dfCliente.to_csv('DimCliente_Actualizado.csv', index=False, sep=';')
dfEmpleado.to_csv('DimEmpleado_Actualizado.csv', index=False, sep=';')
dfFP.to_csv('DimFP_Actualizado.csv', index=False, sep=';')
dfMarca.to_csv('DimMarca_Actualizado.csv', index=False, sep=';')
dfProducto.to_csv('DimProducto_Actualizado.csv', index=False, sep=';')
dfSubCategoria.to_csv('DimSubCategoria_Actualizado.csv', index=False, sep=';')
dfTiempo.to_csv('DimTiempo_Actualizado.csv', index=False, sep=';')
dfVentas.to_csv('DimVentas_Actualizado.csv', index=False, sep=';')

# %% [markdown]
# ##CONEXION CON GOOGLE DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df_drive1 = pd.read_csv('/content/drive/MyDrive/Csv/Entregable_csv/DimCategoria_Actualizado.csv')
df_drive2 = pd.read_csv('/content/drive/MyDrive/Csv/Entregable_csv/DimCliente_Actualizado.csv')
df_drive3 = pd.read_csv('/content/drive/MyDrive/Csv/Entregable_csv/DimEmpleado_Actualizado.csv')
df_drive4 = pd.read_csv('/content/drive/MyDrive/Csv/Entregable_csv/DimFP_Actualizado.csv')
df_drive5 = pd.read_csv('/content/drive/MyDrive/Csv/Entregable_csv/DimMarca_Actualizado.csv')
df_drive6 = pd.read_csv('/content/drive/MyDrive/Csv/Entregable_csv/DimMes.csv')
df_drive7 = pd.read_csv('/content/drive/MyDrive/Csv/Entregable_csv/DimProducto_Actualizado.csv')
df_drive8 = pd.read_csv('/content/drive/MyDrive/Csv/Entregable_csv/DimSubCategoria_Actualizado.csv')
df_drive9 = pd.read_csv('/content/drive/MyDrive/Csv/Entregable_csv/DimTiempo_Actualizado.csv')
df_drive10 = pd.read_csv('/content/drive/MyDrive/Csv/Entregable_csv/DimVentas_Actualizado.csv')

# %%
df_drive1.head(5)
# Out:
#    id_cat    nom_cat
# 0       1  Abarrotes
# 1       2    Lácteos
# 2       3   Gaseosas
# 3       4    Licores
# 4       5  Panadería

# %% [markdown]
# ##CONFIGURACION CON BIGQUERY

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
from os import write
from google.cloud import bigquery
client = bigquery.Client(project='virtual-ellipse-460616-f3')
job_config = bigquery.LoadJobConfig(
    write_disposition = "WRITE_TRUNCATE"
    )

dataframes_to_upload = {
    "DimCategoria": df_drive1,
    "DimCliente": df_drive2,
    "DimEmpleado": df_drive3,
    "DimFP": df_drive4,
    "DimMarca": df_drive5,
    "DimMes": df_drive6,
    "DimProducto": df_drive7,
    "DimSubCategoria": df_drive8,
    "DimTiempo": df_drive9,
    "DimVentas": df_drive10
}

for table_name, dataframe in dataframes_to_upload.items():
    table_id = f"Ventas.{table_name}"
    job = client.load_table_from_dataframe(dataframe, table_id, job_config=job_config)
    job.result()

    # Chequeo 1: Verificar el estado del trabajo
    if job.state == 'DONE' and job.error_result is None:
        print(f"La carga para {table_name} se completó exitosamente")
    else:
        print(f"La carga para {table_name} no se completó exitosamente")
        # Imprimir detalles del error
        print("Errores")
        for error in job.errors:
            print(error)

    # Chequeo 2: Contar las filas de la tabla para asegurarse de que los datos se cargaron
    table = client.get_table(table_id)
    print(f"La tabla cargada {table_name} tiene {table.num_rows} filas")

    # Get the corresponding original dataframe for comparison
    original_df_name = f"df{table_name.replace('Dim', '').replace('Ventas', '')}" if table_name != 'DimVentas' else 'dfVentas'
    if original_df_name in globals():
        num_filas_df = globals()[original_df_name].shape[0]
        if table.num_rows == num_filas_df:
            print(f'La carga para {table_name} fue exitosa. El dataframe y la tabla en BigQuery tiene {num_filas_df} filas')
        else:
            print(f'La carga para {table_name} no fue exitosa, posible discrepancia. Dataframe tiene {num_filas_df} filas, tabla tiene {table.num_rows} filas')
    else:
        print(f"Could not verify row count for {table_name} as original dataframe {original_df_name} not found.")
# Out:
# La carga para DimCategoria se completó exitosamente
# La tabla cargada DimCategoria tiene 24 filas
# Could not verify row count for DimCategoria as original dataframe dfCategoria not found.
# La carga para DimCliente se completó exitosamente
# La tabla cargada DimCliente tiene 25 filas
# La carga para DimCliente fue exitosa. El dataframe y la tabla en BigQuery tiene 25 filas
# La carga para DimEmpleado se completó exitosamente
# La tabla cargada DimEmpleado tiene 48 filas
# La carga para DimEmpleado fue exitosa. El dataframe y la tabla en BigQuery tiene 48 filas
# La carga para DimFP se completó exitosamente
# La tabla cargada DimFP tiene 13 filas
# La carga para DimFP fue exitosa. El dataframe y la tabla en BigQuery tiene 13 filas
# La carga para DimMarca se completó exitosamente
# La tabla cargada DimMarca tiene 25 filas
# La carga para DimMarca fue exitosa. El dataframe y la tabla en BigQuery tiene 25 filas
# La carga para DimMes se completó exitosamente
# ...
